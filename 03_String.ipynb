# %%
### String ###

my_string="mi string"
my_other_string="Mi otro string"

print(len(my_string))
print(len(my_other_string))
print(my_string+""+my_oter_string)

my_new_line_string="este es un string\ncon salto de linea"
print(my_new_line_string)

my_tab_s



# Desempaquetado de caracteres
language = "puthon"
a, b, c, d, e, f =language
print(a)
print(e)

# Division

language_slice = language[1:3] #Cuanderecha do es negativo contamos de isquierda a derecha y cuando es positiva de
print(language_slice)

language_slice =language[1:]
print(language_slice)

languaje_slice language[-2]
print(language_slice)

language_slice language[0:6:2]
print(language_slice)

# Reverso
reversc_language=language[::-1]
print(reversed_language)

# Funciones del lenguaje
#print(language.capitalize())
#print(language.upper())
#print(language.count("t"))
#print(language.isnumeric())
#print("1".isnumeric())
#print(language.lower())
#print(language.lawer().isupper())
#print(language.startswith("´Py"))
#print("Py"=="Py")
